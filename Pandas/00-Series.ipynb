# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series
#
#
# The first main data type we will learn about for pandas is the Series data type. Let's import Pandas and explore the Series object.
#
# A Series is very similar to a NumPy array (in fact it is built on top of the NumPy array object). What differentiates the NumPy array from a Series, is that a Series can have axis labels, meaning it can be indexed by a label, instead of just a number location. It also doesn't need to hold numeric data, it can hold any arbitrary Python Object.

# %% [markdown]
# ### Creating a Series from Python Objects

# %% [markdown]
# #### Index and Data Lists

# %%
my_index = ['USA', 'Canada', 'Mexico', 'Brazil']

# %%
mydata = [1776, 1867, 1821, 1822]

# %%
my_series = pd.Series(data=mydata)

# %%
my_series
# Out:
# 0    1776
# 1    1867
# 2    1821
# 3    1822
# dtype: int64

# %%
pd.Series(data=mydata, index=my_index)
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# Brazil    1822
# dtype: int64

# %%
rand_data = np.random.randint(0, 100, 4)
rand_data
# Out:
# array([52, 84, 65, 51])

# %%
names = ['Andrews', 'Joe', 'Claire', 'Joana']

# %%
ages = pd.Series(rand_data, names)

# %%
ages
# Out:
# Andrews    52
# Joe        84
# Claire     65
# Joana      51
# dtype: int64

# %%
ages['Joe']
# Out:
# np.int64(84)

# %% [markdown]
# #### From Dictionary

# %%
ages = {'Sammy':5, 'Frank': 10, 'Spike':7}

# %%
ages
# Out:
# {'Sammy': 5, 'Frank': 10, 'Spike': 7}

# %%
pd.Series(ages)
# Out:
# Sammy     5
# Frank    10
# Spike     7
# dtype: int64

# %% [markdown]
# ### Key Ideas of a Series

# %% [markdown]
# #### Named Index

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
# Convert into Pandas Series
sales_Q1 = pd.Series(q1)
sales_Q2 = pd.Series(q2)

# %%
sales_Q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
# Call values based on Named Index
sales_Q1['Japan']
# Out:
# np.int64(80)

# %%
# Integer Based Location information also retained!
sales_Q1[0]
# Out:
# /tmp/ipykernel_36371/3172792608.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales_Q1[0]
# np.int64(80)

# %% [markdown]
# ### Operations

# %%
sales_Q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_Q1 * 2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
sales_Q2 / 2
# Out:
# Brazil     50.0
# China     250.0
# India     105.0
# USA       130.0
# dtype: float64

# %%
sales_Q1 + sales_Q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
# You can fill these with any value you want
sales_Q1.add(sales_Q2,fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64
